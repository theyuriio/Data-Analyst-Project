# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv(r"D:\Top_rated_movies1.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of           id                                 title  \
# 0     168705                            BloodRayne
# 1      19766                    Inspector Gadget 2
# 2     248705            The Visitors: Bastille Day
# 3      17711  The Adventures of Rocky & Bullwinkle
# 4        580                     Jaws: The Revenge
# ...      ...                                   ...
# 8826   12142                     Alone in the Dark
# 8827    5491                     Battlefield Earth
# 8828   11059                     House of the Dead
# 8829   14164                  Dragonball Evolution
# 8830   40016            Birdemic: Shock and Terror
#
#                                                overview  popularity  \
# 0     In 18th-century Romania, after spending much o...      17.499
# 1     After capturing Claw, all the criminals have g...      20.772
# 2     Stuck in the corridors of time, Godefroy de Mo...      18.828
# 3     Rocky and Bullwinkle have been living off the ...      16.436
# 4     After another deadly shark attack, Ellen Brody...      30.996
# ...                                                 ...         ...
# 8826  Edward Carnby is a private investigator specia...      12.499
# 8827  In the year 3000, man is no match for the Psyc...      19.133
# 8828  Set on an island off the coast, a techno rave ...      10.795
# 8829  On his 18th birthday, Goku receives a mystical...      38.646
# 8830  A platoon of eagles and vultures attacks the r...      13.853
#
#      release_date  vote_average  vote_count
# 0      2005-10-22         4.105         501
# 1      2003-03-11         4.100         342
# 2      2016-03-23         4.090         636
# 3      2000-06-30         4.075         335
# 4      1987-07-17         4.064         931
# ...           ...           ...         ...
# 8826   2005-01-28         3.228         550
# 8827   2000-05-12         3.221         761
# 8828   2003-04-11         3.100         359
# 8829   2009-03-12         2.891        1925
# 8830   2010-02-27         2.106         306
#
# [8831 rows x 7 columns]>

# %%
df.head(10)
# Out:
#        id                                      title  \
# 0  168705                                 BloodRayne
# 1   19766                         Inspector Gadget 2
# 2  248705                 The Visitors: Bastille Day
# 3   17711       The Adventures of Rocky & Bullwinkle
# 4     580                          Jaws: The Revenge
# 5   21435  French Fried Vacations 3: Friends Forever
# 6    8046                                      Gigli
# 7    7278                          Meet the Spartans
# 8   17473                                   The Room
# 9  505423                                     Wounds
#
#                                             overview  popularity release_date  \
# 0  In 18th-century Romania, after spending much o...      17.499   2005-10-22
# 1  After capturing Claw, all the criminals have g...      20.772   2003-03-11
# 2  Stuck in the corridors of time, Godefroy de Mo...      18.828   2016-03-23
# 3  Rocky and Bullwinkle have been living off the ...      16.436   2000-06-30
# 4  After another deadly shark attack, Ellen Brody...      30.996   1987-07-17
# 5  After the Club Med and skiing, what happened t...       9.060   2006-02-01
# 6  Gigli is ordered to kidnap the psychologically...      14.759   2003-08-01
# 7  The heroic Leonidas, armed with nothing but le...      45.963   2008-01-24
# 8  Johnny is a successful banker with great respe...      14.775   2003-06-27
# 9  Disturbing and mysterious things begin to happ...      21.921   2019-01-26
#
#    vote_average  vote_count
# 0         4.105         501
# 1         4.100         342
# 2         4.090         636
# 3         4.075         335
# 4         4.064         931
# 5         4.058         680
# 6         4.042         426
# 7         4.000        1555
# 8         4.035        1298
# 9         4.021         739

# %%
df.describe()
# Out:
#                  id   popularity  vote_average    vote_count
# count  8.831000e+03  8831.000000   8831.000000   8831.000000
# mean   1.775555e+05    33.136177      6.639059   1969.126486
# std    2.352400e+05    49.108903      0.794924   3059.560533
# min    5.000000e+00     0.600000      2.106000      1.000000
# 25%    9.927500e+03    16.729000      6.113500    469.000000
# 50%    3.387500e+04    23.804000      6.662000    846.000000
# 75%    3.345215e+05    35.751500      7.205000   1966.000000
# max    1.151534e+06  1766.305000      8.708000  34794.000000

# %%
df.isna().sum()
# Out:
# id              0
# title           0
# overview        1
# popularity      0
# release_date    0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
    ###DISTRIBUTION OF POPULARITY

sns.histplot(data=df, x='popularity', bins=20)
# Out:
# <Axes: xlabel='popularity', ylabel='Count'>

# %%
    ###Number of Movies Released Each Year
df['release_date'] = pd.to_datetime(df['release_date'])
df['release_year'] = df['release_date'].dt.year

top_years = df['release_year'].value_counts().nlargest(50).index
df_top_years = df[df['release_year'].isin(top_years)]

plt.figure(figsize=(14, 8))
sns.countplot(x='release_year', data=df_top_years, palette='seismic_r')
plt.title('Number of Movies Released Each Year (Top 50 Years)')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\hylli\AppData\Local\Temp\ipykernel_11204\2435674781.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='release_year', data=df_top_years, palette='seismic_r')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 10
#       8 plt.figure(figsize=(14, 8))
#       9 sns.countplot(x='release_year', data=df_top_years, palette='seismic_r')
# ---> 10 plt.title('Number of Movies Released Each Year (Top 50 Years)')
#      11 plt.xlabel('Year')
#      12 plt.ylabel('Number of Movies')
#
# TypeError: 'str' object is not callable

# %%
    ###VOTE AVERAGE DISTRIBUTION

fig = sns.histplot(df, x='vote_average', bins=12, kde=True)

# %%
sns.scatterplot(data=df, x='popularity', y='vote_average', hue='vote_count')

plt.figure(figsize=(14,8))

# %%
    ###CORRELATION HEATMAP
corr_matrix = df[['popularity', 'vote_average', 'vote_count']].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 6
#       4 plt.figure(figsize=(10, 6))
#       5 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=.5)
# ----> 6 plt.title('Correlation Heatmap')
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %%
top_votes = df.nlargest(10, 'vote_count')

plt.figure(figsize=(10, 7))
sns.barplot(x='vote_count', y='title', data=top_votes, palette='Blues_d')
plt.xlabel('Number of Votes')
plt.ylabel('Movie Title')
plt.show()
# Out:
# C:\Users\hylli\AppData\Local\Temp\ipykernel_11204\3918884920.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='vote_count', y='title', data=top_votes, palette='Blues_d')

# %%
top_votes = df.nsmallest(10, 'vote_count')

plt.figure(figsize=(10, 7))
sns.barplot(x='vote_count', y='title', data=top_votes, palette='Blues_d')
plt.xlabel('Number of Votes')
plt.ylabel('Movie Title')
plt.show()
# Out:
# C:\Users\hylli\AppData\Local\Temp\ipykernel_11204\382396292.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='vote_count', y='title', data=top_votes, palette='Blues_d')

# %%
    ###TOP 10 MOVIES WITH HIGHEST POPULARITY
top_votes = df.nlargest(10, 'popularity')

plt.figure(figsize=(10, 7))
sns.barplot(x='popularity', y='title', data=top_votes, palette='Blues_d')
plt.ylabel('Movie Title')
plt.show()
# Out:
# C:\Users\hylli\AppData\Local\Temp\ipykernel_11204\2922922504.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='popularity', y='title', data=top_votes, palette='Blues_d')

# %%
    ###BOTTOM 10 MOVIES WITH LOWEST POPULARITY
top_votes = df.nsmallest(10, 'popularity')

plt.figure(figsize=(10, 7))
sns.barplot(x='popularity', y='title', data=top_votes, palette='Blues_d')
plt.xlabel('Number of Votes')
plt.ylabel('Movie Title')
plt.show()
# Out:
# C:\Users\hylli\AppData\Local\Temp\ipykernel_11204\2883217617.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='popularity', y='title', data=top_votes, palette='Blues_d')

# %%
time_series_data = df.groupby('release_year').agg({'popularity': 'mean', 'vote_count': 'mean'}).reset_index()

# Plotting Time Series for Popularity
plt.figure(figsize=(12, 6))
sns.lineplot(x='release_year', y='popularity', data=time_series_data, color='blue')
plt.xlabel('Release Year')
plt.ylabel('Average Popularity')
plt.show()
